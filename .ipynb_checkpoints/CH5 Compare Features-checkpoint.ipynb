# %% [markdown]
# ## Raw Original Features

# %%
import joblib
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier


# %matplotlib inline

# %%
train_features = pd.read_csv('data/final_data/train_features_raw.csv')
train_labels = pd.read_csv('data/final_data/train_labels.csv')

train_features.head()
# Out:
#      Pclass       Sex  Age_clean     SibSp     Parch      Fare     Cabin  \
# 0 -0.408652  0.737125   2.570771 -0.464063 -0.468427 -0.412724  0.450064
# 1  0.803682  0.737125  -1.673694  2.692745  0.794906 -0.066661  0.450064
# 2  0.803682  0.737125   0.212735 -0.464063 -0.468427  0.441904  0.450064
# 3  0.803682 -1.356623  -0.730480  0.325139 -0.468427 -0.425266  0.450064
# 4 -0.408652 -1.356623  -0.101670 -0.464063 -0.468427 -0.366273  0.450064
#
#    Embarked
# 0  0.573494
# 1 -0.718682
# 2  0.573494
# 3  0.573494
# 4  0.573494

# %%
# Generate correlation matrix heat map
matrix = np.triu(train_features.corr())
sns.heatmap(train_features.corr(), annot=True, fmt='.1f', vmin=-1, vmax=1, center= 0, cmap='coolwarm', mask=matrix)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### GridSearchCV

# %%
def print_results(results):
    print("BEST PARAMS: {}\n".format(results.best_params_))
    
    means = results.cv_results_['mean_test_score']
    stds = results.cv_results_['std_test_score']
    for mean, std, params in zip(means, stds, results.cv_results_['params']):
        print('{} (+/-{}) for {}'.format(round(mean, 3), round(std *2, 3), params))

# %%
# Conduct search for best params while running cross-validation (GridSearchCV)
rf = RandomForestClassifier()
parameters = {
    'n_estimators': [2**i for i in range(3, 10)],
    'max_depth': [2, 4, 8, 16, 32, None]
}

cv = GridSearchCV(rf, parameters, cv=5)
cv.fit(train_features, train_labels.values.ravel())

print_results(cv)
# Out:
# BEST PARAMS: {'max_depth': 8, 'n_estimators': 128}
#
# 0.788 (+/-0.128) for {'max_depth': 2, 'n_estimators': 8}
# 0.802 (+/-0.101) for {'max_depth': 2, 'n_estimators': 16}
# 0.792 (+/-0.096) for {'max_depth': 2, 'n_estimators': 32}
# 0.79 (+/-0.095) for {'max_depth': 2, 'n_estimators': 64}
# 0.803 (+/-0.102) for {'max_depth': 2, 'n_estimators': 128}
# 0.796 (+/-0.102) for {'max_depth': 2, 'n_estimators': 256}
# 0.79 (+/-0.113) for {'max_depth': 2, 'n_estimators': 512}
# 0.82 (+/-0.102) for {'max_depth': 4, 'n_estimators': 8}
# 0.824 (+/-0.102) for {'max_depth': 4, 'n_estimators': 16}
# 0.83 (+/-0.075) for {'max_depth': 4, 'n_estimators': 32}
# 0.826 (+/-0.137) for {'max_depth': 4, 'n_estimators': 64}
# 0.82 (+/-0.118) for {'max_depth': 4, 'n_estimators': 128}
# 0.82 (+/-0.114) for {'max_depth': 4, 'n_estimators': 256}
# 0.824 (+/-0.098) for {'max_depth': 4, 'n_estimators': 512}
# 0.833 (+/-0.059) for {'max_depth': 8, 'n_estimators': 8}
# 0.83 (+/-0.057) for {'max_depth': 8, 'n_estimators': 16}
# 0.828 (+/-0.08) for {'max_depth': 8, 'n_estimators': 32}
# 0.835 (+/-0.058) for {'max_depth': 8, 'n_estimators': 64}
# 0.856 (+/-0.041) for {'max_depth': 8, 'n_estimators': 128}
# 0.841 (+/-0.075) for {'max_depth': 8, 'n_estimators': 256}
# 0.845 (+/-0.059) for {'max_depth': 8, 'n_estimators': 512}
# 0.809 (+/-0.072) for {'max_depth': 16, 'n_estimators': 8}
# 0.818 (+/-0.074) for {'max_depth': 16, 'n_estimators': 16}
# 0.815 (+/-0.051) for {'max_depth': 16, 'n_estimators': 32}
# 0.826 (+/-0.073) for {'max_depth': 16, 'n_estimators': 64}
# 0.824 (+/-0.05) for {'max_depth': 16, 'n_estimators': 128}
# 0.818 (+/-0.065) for {'max_depth': 16, 'n_estimators': 256}
# 0.826 (+/-0.064) for {'max_depth': 16, 'n_estimators': 512}
# 0.792 (+/-0.042) for {'max_depth': 32, 'n_estimators': 8}
# 0.805 (+/-0.018) for {'max_depth': 32, 'n_estimators': 16}
# 0.815 (+/-0.046) for {'max_depth': 32, 'n_estimators': 32}
# 0.822 (+/-0.053) for {'max_depth': 32, 'n_estimators': 64}
# 0.817 (+/-0.053) for {'max_depth': 32, 'n_estimators': 128}
# 0.824 (+/-0.054) for {'max_depth': 32, 'n_estimators': 256}
# 0.822 (+/-0.06) for {'max_depth': 32, 'n_estimators': 512}
# 0.82 (+/-0.075) for {'max_depth': None, 'n_estimators': 8}
# 0.805 (+/-0.052) for {'max_depth': None, 'n_estimators': 16}
# 0.813 (+/-0.07) for {'max_depth': None, 'n_estimators': 32}
# 0.826 (+/-0.053) for {'max_depth': None, 'n_estimators': 64}
# 0.811 (+/-0.059) for {'max_depth': None, 'n_estimators': 128}
# 0.822 (+/-0.058) for {'max_depth': None, 'n_estimators': 256}
# 0.818 (+/-0.059) for {'max_depth': None, 'n_estimators': 512}

# %% [markdown]
# ### Feature Importance

# %%
# Generate feature importance plot
feat_imp = cv.best_estimator_.feature_importances_
indices = np.argsort(feat_imp)
plt.yticks(range(len(indices)), [train_features.columns[i] for i in indices])
plt.barh(range(len(indices)), feat_imp[indices], color='r', align='center')
plt.show()

# %% [markdown]
# ### Write Out Pickled Model

# %%
# Write out the model fit on the whole training set
joblib.dump(cv.best_estimator_, 'models/mdl_raw_original_features.pkl')
# Out:
# ['models/mdl_raw_original_features.pkl']

# %% [markdown]
# ## Cleaned Original Features

# %%
train_features = pd.read_csv('data/final_data/train_features_original.csv')
train_features.head()
# Out:
#      Pclass       Sex  Age_clean     SibSp     Parch  Fare_clean     Cabin  \
# 0 -0.408652  0.737125   2.570771 -0.464063 -0.468427   -0.483840  0.450064
# 1  0.803682  0.737125  -1.673694  2.692745  0.794906   -0.046993  0.450064
# 2  0.803682  0.737125   0.212735 -0.464063 -0.468427    0.594986  0.450064
# 3  0.803682 -1.356623  -0.730480  0.325139 -0.468427   -0.499672  0.450064
# 4 -0.408652 -1.356623  -0.101670 -0.464063 -0.468427   -0.425203  0.450064
#
#    Embarked_clean
# 0        0.545364
# 1       -0.334468
# 2        0.545364
# 3        0.545364
# 4        0.545364

# %%
# Generate correlation matrix heat map
matrix = np.triu(train_features.corr())
sns.heatmap(train_features.corr(), annot=True, fmt='.1f', vmin=-1, vmax=1, center= 0, cmap= 'coolwarm', mask=matrix)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### GridSearchCV

# %%
def print_results(results):
    print('BEST PARAMS: {}\n'.format(results.best_params_))

    means = results.cv_results_['mean_test_score']
    stds = results.cv_results_['std_test_score']
    for mean, std, params in zip(means, stds, results.cv_results_['params']):
        print('{} (+/-{}) for {}'.format(round(mean, 3), round(std * 2, 3), params))

# %%
# Conduct search for best params while running cross-validation (GridSearchCV)
rf = RandomForestClassifier()
parameters = {
    'n_estimators': [2**i for i in range(3, 10)],
    'max_depth': [2, 4, 8, 16, 32, None]
}
cv = GridSearchCV(rf, parameters, cv=5)
cv.fit(train_features, train_labels.values.ravel())

print_results(cv)

# %%
# Generate feature importance plot
feat_imp = cv.best_estimator_.feature_importances_
indices = np.argsort(feat_imp)
plt.yticks(range(len(indices)), [train_features.columns[i] for i in indices])
plt.barh(range(len(indices)), feat_imp[indices], color='r', align='center')
plt.show()

# %%
# Write out the model fit on the whole training set
joblib.dump(cv.best_estimator_, 'models/mdl_cleaned_original_features.pkl')
